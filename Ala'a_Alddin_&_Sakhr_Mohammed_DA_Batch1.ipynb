# %% [markdown]
# #About the Dataset
# ***The sample Dataset includes data for the Sales of multiple products sold by the store along with subsequent information related to geography, Product categories, and subcategories, sales, and profits, segmentation amongst the consumers, etc. This sample Dataset presents a common use case, from which you could gather useful insights from the Sales data in order to improve the Marketing and Sales strategies. you can learn about various operations and elements using this sample Dataset and come up with better strategies to improve and grow the business more.***

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #ِAccess to csv file in my drive files

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Read the Dataset and check the head

# %%
store=pd.read_csv("/content/drive/MyDrive/Store.csv")
store.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  6/1/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  8/1/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  5/1/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  5/1/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  8/1/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name sales quantity  \
# ...

# %% [markdown]
# #show all dataset

# %%
store
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  6/1/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  8/1/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  5/1/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  5/1/2011    Second Class
# 4        IN-2011-47883    1/1/2011  8/1/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  31-12-2014  4/1/2015  Standard Class
# 51286     MO-2014-2560  31-12-2014  5/1/2015  Standard Class
# 51287   MX-2014-110527  31-12-2014  2/1/2015    Second Class
# 51288   MX-2014-114783  31-12-2014  6/1/2015  Standard Class
# 51289   CA-2014-156720  31-12-2014  4/1/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
store.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
store.shape
# Out:
# (51290, 21)

# %% [markdown]
# # DATA Cleaning

# %% [markdown]
# #check null values existance

# %%
store.isnull()
# Out:
#        order_id  order_date  ship_date  ship_mode  customer_name  segment  \
# 0         False       False      False      False          False    False
# 1         False       False      False      False          False    False
# 2         False       False      False      False          False    False
# 3         False       False      False      False          False    False
# 4         False       False      False      False          False    False
# ...         ...         ...        ...        ...            ...      ...
# 51285     False       False      False      False          False    False
# 51286     False       False      False      False          False    False
# 51287     False       False      False      False          False    False
# 51288     False       False      False      False          False    False
# 51289     False       False      False      False          False    False
#
#        state  country  market  region  ...  category  sub_category  \
# ...

# %% [markdown]
# #checking for duplicate data

# %%
store.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #check information

# %%
store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        51290 non-null  object
#  1   order_date      51290 non-null  object
#  2   ship_date       51290 non-null  object
#  3   ship_mode       51290 non-null  object
#  4   customer_name   51290 non-null  object
#  5   segment         51290 non-null  object
#  6   state           51290 non-null  object
#  7   country         51290 non-null  object
#  8   market          51290 non-null  object
#  9   region          51290 non-null  object
#  10  product_id      51290 non-null  object
#  11  category        51290 non-null  object
#  12  sub_category    51290 non-null  object
#  13  product_name    51290 non-null  object
#  14  sales           51290 non-null  object
#  15  quantity        51290 non-null  int64
#  16  discount        51290 non-null  float64
# ...

# %%
# to change 'sales' index from object type to integer number
store["sales"]=store["sales"].str.replace(',',"")
store["sales"]=pd.to_numeric(store["sales"])

# %%
store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        51290 non-null  object
#  1   order_date      51290 non-null  object
#  2   ship_date       51290 non-null  object
#  3   ship_mode       51290 non-null  object
#  4   customer_name   51290 non-null  object
#  5   segment         51290 non-null  object
#  6   state           51290 non-null  object
#  7   country         51290 non-null  object
#  8   market          51290 non-null  object
#  9   region          51290 non-null  object
#  10  product_id      51290 non-null  object
#  11  category        51290 non-null  object
#  12  sub_category    51290 non-null  object
#  13  product_name    51290 non-null  object
#  14  sales           51290 non-null  int64
#  15  quantity        51290 non-null  int64
#  16  discount        51290 non-null  float64
# ...

# %% [markdown]
# # NOW Our Data is ready, lets analyze our data

# %% [markdown]
# # data statistics

# %%
store.describe()
# Out:
#               sales      quantity      discount        profit  shipping_cost  \
# count  51290.000000  51290.000000  51290.000000  51290.000000   51290.000000
# mean     246.498440      3.476545      0.142908     28.641740      26.375915
# std      487.567175      2.278766      0.212280    174.424113      57.296804
# min        0.000000      1.000000      0.000000  -6599.978000       0.000000
# 25%       31.000000      2.000000      0.000000      0.000000       2.610000
# 50%       85.000000      3.000000      0.000000      9.240000       7.790000
# 75%      251.000000      5.000000      0.200000     36.810000      24.450000
# max    22638.000000     14.000000      0.850000   8399.976000     933.570000
#
#                year
# count  51290.000000
# mean    2012.777208
# std        1.098931
# min     2011.000000
# 25%     2012.000000
# 50%     2013.000000
# 75%     2014.000000
# max     2014.000000

# %% [markdown]
# # analyzing consumer countries

# %%
#show number of countries that deals with the store
store["country"].value_counts()
# Out:
# United States    9994
# Australia        2837
# France           2827
# Mexico           2644
# Germany          2065
#                  ...
# Burundi             2
# Chad                2
# Eritrea             2
# Bahrain             2
# South Sudan         2
# Name: country, Length: 147, dtype: int64

# %% [markdown]
# # Top 10 consumer countries

# %%
store["country"].value_counts()[0:10]
# Out:
# United States     9994
# Australia         2837
# France            2827
# Mexico            2644
# Germany           2065
# China             1880
# United Kingdom    1633
# Brazil            1599
# India             1555
# Indonesia         1390
# Name: country, dtype: int64

# %%
#show the number of orders for each country

L1=np.array(["United States","Australia","France","Mexico","Germany","China","United Kingdom","Brazil","India","Indonesia"])
L2=np.array([9994,2837,2827,2644,2065,1880,1633,1599,1555,1390])
sns.barplot(L2,L1)
plt.title("Top 10 consumer countries in world")
plt.xlabel("count")
plt.ylabel("countries")
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'countries')

# %%
# Top 3 consumer countries orders 
Store_US=store[store["country"]=="United States"]
Store_Aus=store[store["country"]=="Australia"]
Store_FR=store[store["country"]=="France"]

# %% [markdown]
# #Analyzing for just top 3 consumer countries orders as per categories and sub-categories

# %%
store["category"].value_counts()
# Out:
# Office Supplies    31273
# Technology         10141
# Furniture           9876
# Name: category, dtype: int64

# %%
store["sub_category"].value_counts()
# Out:
# Binders        6152
# Storage        5059
# Art            4883
# Paper          3538
# Chairs         3434
# Phones         3357
# Furnishings    3170
# Accessories    3075
# Labels         2606
# Envelopes      2435
# Supplies       2425
# Fasteners      2420
# Bookcases      2411
# Copiers        2223
# Appliances     1755
# Machines       1486
# Tables          861
# Name: sub_category, dtype: int64

# %%
#Products by Categories consumed by just Top 3 countries
plt.figure(figsize=(15,10))
plt.title("United States")
sns.set_theme(style="darkgrid")
sns.countplot(x=Store_US["category"],hue=Store_US["sub_category"])
##################################
plt.figure(figsize=(15,10))
plt.title("Australia")
sns.set_theme(style="darkgrid")
sns.countplot(x=Store_Aus["category"],hue=Store_Aus["sub_category"])
##################################
plt.figure(figsize=(15,10))
plt.title("France")
sns.set_theme(style="darkgrid")
sns.countplot(x=Store_FR["category"],hue=Store_FR["sub_category"])
# Out:
# <AxesSubplot:title={'center':'France'}, xlabel='category', ylabel='count'>

# %% [markdown]
# + for the 3 top countries
#
#  the "office supplies" is the most category ordered
#
#  the "blinders" is the most sub_category ordered

# %% [markdown]
# #Analyzing for just top 3 consumer countries orders as per segments and sub-categories

# %%
store["segment"].value_counts()
# Out:
# Consumer       26518
# Corporate      15429
# Home Office     9343
# Name: segment, dtype: int64

# %%
#Products by Categories consumed by just Top 3 countries
plt.figure(figsize=(15,10))
plt.title("United States")
sns.set_theme(style="darkgrid")
sns.countplot(x=Store_US["segment"],hue=Store_US["sub_category"])
##################################
plt.figure(figsize=(15,10))
plt.title("Australia")
sns.set_theme(style="darkgrid")
sns.countplot(x=Store_Aus["segment"],hue=Store_Aus["sub_category"])
##################################
plt.figure(figsize=(15,10))
plt.title("France")
sns.set_theme(style="darkgrid")
sns.countplot(x=Store_FR["segment"],hue=Store_FR["sub_category"])
# Out:
# <AxesSubplot:title={'center':'France'}, xlabel='segment', ylabel='count'>

# %% [markdown]
# # Analyzing shipping mode for each market

# %%
store["ship_mode"].value_counts()
# Out:
# Standard Class    30775
# Second Class      10309
# First Class        7505
# Same Day           2701
# Name: ship_mode, dtype: int64

# %%
plt.figure(figsize=(10,7))
sns.countplot(x=store["market"],hue=store["ship_mode"])
# Out:
# <AxesSubplot:xlabel='market', ylabel='count'>

# %% [markdown]
# we can see that, the most preferred shipment mode is the "standard class" and the lowest market that ship s Canada market and the largest is APAC market.

# %% [markdown]
# # Analyzing shipping mode for each region

# %%
plt.figure(figsize=(10,7))
sns.countplot(x=store["region"],hue=store["ship_mode"])
# Out:
# <AxesSubplot:xlabel='region', ylabel='count'>

# %% [markdown]
# #Analyzing the most common columns in the dataset

# %%
 # function to plot pie and count
def plot_pie_count(colunas):
    Fig, ax = plt.subplots(1,2, figsize=(14,7))
    
    plt.suptitle(f'{colunas}', fontsize=16, fontweight='bold')
    store[colunas].value_counts().plot.pie(autopct='%.2f%%', textprops={'size':14},wedgeprops={'width':0.6, 'edgecolor':'white'},ax=ax[0])
    ax[0].axis('off')
    sns.countplot(x=store[colunas],ax=ax[1],alpha=0.5)
    ax[1].tick_params(axis='x', labelsize=14)
    for i in ax[1].containers:
        ax[1].bar_label(i, label_type='center', rotation=90, fontsize=16)
    plt.xlabel(None)
    plt.tight_layout()
    plt.show()

# %%
columns= ['ship_mode','segment', 'market', 'region','category', 'sub_category', 'order_priority', 'year']
for i in columns:
    plot_pie_count(i)
    print()

# %% [markdown]
# ***as we can see from the charts above, we can give answers for the following questions:-***
#
# + What is the most frequent region in the dataset?
#
#  + 23% of the data is from the Central Region (the highest order count)
#
# + What is the most frequent segment?
#  + 52% of the data is from Consumers (the best segment seller)
#
# + What is the most common category in this dataset?
#  + 61% is office supplies data
#
# + What is the most frequent country?
#  + 35% of the data is the United States
#
# + What is the most frequent product?
#  + 16% is binders (6152 order)
#
# + What is the most frequent ship mode?
#  + 60% is standard class mode
#
# + which year has the highest sales?
#  + 2014 has 34% almost 17500 order
#
# + What is the most order priority?
#  + 16% of orders has medium priority

# %% [markdown]
# #Growth in sales of products over years

# %%
store_2011=store[store["year"]==2011]
store_2011["quantity"].sum()
# Out:
# 31443

# %%
store_2012=store[store["year"]==2012]
store_2012["quantity"].sum()
# Out:
# 38111

# %%
store_2013=store[store["year"]==2013]
store_2013["quantity"].sum()
# Out:
# 48136

# %%
store_2014=store[store["year"]==2014]
store_2014["quantity"].sum()
# Out:
# 60622

# %%
S1=[2011,2012,2013,2014]
S2=[31443,38111,48136,60622]
plt.figure(figsize=(10,7))
sns.barplot(x=S1,y=S2)
plt.xlabel("Years")
plt.ylabel("growth in sales of products")
plt.title("Growth with years")
# Out:
# Text(0.5, 1.0, 'Growth with years')

# %% [markdown]
# we can see that the sales are growing year after year, so that in 2014 in the maximum sales

# %% [markdown]
# #Analyzing Profits

# %% [markdown]
# + **profits vs sales for each year**

# %%
year_profit = store.groupby('year').sum()[['sales','profit']]
year_profit.plot(kind='bar',figsize=(16,5))
plt.title("Sales vs. Profits")
plt.ylabel("In handred thousands")
# Out:
# Text(0, 0.5, 'In handred thousands')

# %% [markdown]
# we can see that 2014 is the most profitable year and has maximum sellings

# %% [markdown]
# + **Profits from the shipping mode point of view**

# %%
shipping_profits = store.groupby('ship_mode').sum()[['shipping_cost','profit']]
shipping_profits.plot(kind='bar',figsize=(16,5))
plt.ylabel("In millions")
# Out:
# Text(0, 0.5, 'In millions')

# %% [markdown]
# we can see that 'standard class' shipping mode is the most profitable mode

# %% [markdown]
# + **Profits from the caterogy point of view**

# %%
category_profits = store.groupby('category').sum()[['sales','profit']]
category_profits.plot(kind='bar',figsize=(16,5))
plt.ylabel("In thousands")
# Out:
# Text(0, 0.5, 'In thousands')

# %% [markdown]
# we can see that "Tecnology"  is the most profitable category

# %% [markdown]
# + **Profits from the sub_caterogy point of view**

# %%
sub_category_profits = store.groupby('sub_category').sum()[['sales','profit']]
sub_category_profits.plot(kind='bar',figsize=(16,5))
plt.ylabel("In thousands")
# Out:
# Text(0, 0.5, 'In thousands')

# %% [markdown]
# + **Profits from the segments point of view**

# %%
category_profits = store.groupby('segment').sum()[['sales','profit']]
category_profits.plot(kind='bar',figsize=(16,5))
plt.ylabel("In millions")
# Out:
# Text(0, 0.5, 'In millions')

# %% [markdown]
# we can see that "consumer" segment  is the most profitable segment

# %% [markdown]
# + **Profits of each market**

# %%
market_profits = store.groupby('market').sum()[['sales', 'profit']]
market_profits.plot(kind='bar',figsize=(16,5))
plt.ylabel("In millions")
# Out:
# Text(0, 0.5, 'In millions')

# %% [markdown]
# we can see from above visualization that most profit is comming from APAC market followed by EU market, and lowest sales for Canada market and there are any profits from this market

# %% [markdown]
# + **Profits of each region**

# %%
region_profits = store.groupby('region').sum()[['sales', 'profit']]
region_profits.plot(kind='bar',figsize=(16,5))
plt.ylabel("In millions")
# Out:
# Text(0, 0.5, 'In millions')

# %% [markdown]
# + **Most discount given for each region**

# %%
region_dis= store.groupby(['region']).sum()
region_dis.reset_index(inplace=True)

fig, ax = plt.subplots(figsize=(15, 5))
sns.barplot(x='region', y='discount', data=region_dis)
plt.xticks(rotation=90)
plt.show();

# %% [markdown]
# we can see from the two above visualizations that Store is offering high discounts in the Central Region and despite that, the Central region is still the most profitable Region.

# %% [markdown]
# # profits & losses

# %% [markdown]
# + **Top 10 profitable countries**

# %%
store.groupby(['country']).sum()[['profit']].sort_values(by="profit",ascending=False).nlargest(n=10, columns=['profit']).plot.bar(color="green")
plt.show()

# %% [markdown]
# + **last 10 profitable countries or losseing countries**

# %%
store.groupby(['country']).sum()[['profit']].sort_values(by="profit",ascending=False).nsmallest(n=10, columns=['profit']).plot.bar(color="red")
plt.show()

# %%
#in numbers
print("for specific numbers..", '\n')
coun_stat = store.groupby('country')['profit'].sum().sort_values(ascending=False)
print("contries with greateer profits:\n", (coun_stat.head(10)), '\n')
print("contries with greateer losses:\n", (coun_stat.tail(10)))
# Out:
# for specific numbers..
#
# contries with greateer profits:
#  country
# United States     286397.02170
# China             150683.08500
# India             129071.83500
# United Kingdom    111900.15000
# France            109029.00300
# Germany           107322.82050
# Australia         105484.96300
# Mexico            102818.09752
# Spain              54390.12000
# El Salvador        42023.24320
# Name: profit, dtype: float64
#
# contries with greateer losses:
#  country
# South Korea   -12792.83100
# Philippines   -16128.22500
# Sweden        -17519.36700
# Panama        -17723.45248
# Argentina     -18693.79672
# Pakistan      -22446.64800
# Honduras      -29482.37140
# Netherlands   -41070.07500
# Nigeria       -80750.71800
# Turkey        -98447.23200
# Name: profit, dtype: float64

# %% [markdown]
# + **Most 10 countries given a discount**

# %%
store.groupby(['country']).sum()[['discount']].sort_values(by="discount",ascending=False).nlargest(n=10, columns=['discount']).plot.bar(color="blue")
plt.show()

# %% [markdown]
# we can see from the three above visualizations that Store is offering high discounts for "United states" and despite that, United States is still the most profitable country.
#
# on the other hand, the second country which is given high discount "Turkey" is still the most lossable country!!
#
# **so, the discount given dose not effect in pofits**

# %%
plt.figure(figsize=(16,10))
sns.scatterplot(data=store, x= "sales", y="profit");

# %% [markdown]
# according to the pervious chart we can see there are profitable sales and losses

# %% [markdown]
# # calculate net profit

# %%
#define profit and loss
store_profit=store[store['profit'] > 0]
store_loss=store[store['profit'] < 0]

# %%
#Shape of the profit Dataframe
store_profit.shape
# Out:
# (38079, 21)

# %%
#Shape of the loss Dataframe
store_loss.shape
# Out:
# (12543, 21)

# %%
#calculating total profit
Total_Profit = store_profit['profit'].sum()
Total_Profit
# Out:
# 2389392.212

# %%
#calculating total loss
Total_loss=np.negative(store_loss['profit'].sum())
Total_loss
# Out:
# 920357.39072

# %%
Net_Profit = Total_Profit - Total_loss
Net_Profit
# Out:
# 1469034.8212799998

# %%
#create a dataFrame o visualize the bervious steps
Df_Net_Profit=pd.DataFrame({'Total_Profit': {0: 2389392},
                            'Total_loss':{0: 920357},
                            ''         '':{0: '='},
                            'Net_Profit':{0: 1469035}})
Df_Net_Profit
# Out:
#    Total_Profit  Total_loss     Net_Profit
# 0       2389392      920357  =     1469035

# %%
Df_Net_Profit.plot(kind='bar')
plt.xlabel("profits")
plt.ylabel("In millions")
# Out:
# Text(0, 0.5, 'In millions')

# %% [markdown]
# #Analyzing losses

# %%
#Adding the categorical columns to the bar graph, to visualize the average of each value.
cols = ['ship_mode','segment', 'market', 'region','category', 'sub_category']

plt.figure(figsize=(14,40))
for i, col in enumerate(cols):
    ax = plt.subplot(6,2,i+1)
    sns.barplot( x=store_loss['profit'], y=store_loss[col], alpha=0.5,ci=None)
    sns.set_theme(style="darkgrid")
    plt.title(f'{col} | Profit', fontsize=14, fontweight='bold')
    plt.yticks(fontsize=14)
    plt.xlabel(None)
    plt.ylabel(None)
    for i in ax.containers:
        ax.bar_label(i,fontsize=14, label_type='center', padding=30)
plt.tight_layout()
plt.show()

# %% [markdown]
# **After splitting data into a subset with only negative data(losses), we answered the questions and it showed us in the graphs:**
#
# + Which category has negative profit by region?
#   + Furniture category brought negative results in several regions.
#
# + Which product had the most negative profit?
#  + The answer already answered above, furniture as a table was the one that presented the most negative return in several regions.
#
# + Which region had a negative profit return?
#  + North Asia
#
# + Which ship_mode had a negative profit return?
#  + same day shipment mode

# %% [markdown]
# # THE SUGGESTED DECISIONS
# First, let’s present the highest in sales, profit, and loss for each attribute
#
# **Region**
# -	Sales: ‘Central’, ‘South’
#
# -	Profit: ‘Central’, ‘North’
#
# -	Loss: 'oceania'
#
# **Country**
# -	Sales: ‘US’, ‘Australia’
#
# -	Profit: ‘US’, ‘China’, ‘India’
#
# -	Loss: 'Netherlands' , 'Nigeria' , 'Turkey'
#
# **Category**
# -	Sales: ‘Technology’, ‘Furniture’
#
# -	Profit: ‘Technology’, ‘Office Supplies’
#
# **Sub-Category**
# -	Sales: ‘Phones’, ‘Copies’
#
# -	Profit: ‘Copies’, ‘Phones’
#
# -	Loss: ‘Tables’
#
# **Ship Mode**
# -	Sales: ‘Standard Class’, ‘Second Class’
#
# -	Profit: ‘Standard Class’, ‘Second Class’
#
# -	Loss: 'same day'
#
# Proposals to Increase Sales, Profits and Profitability, reducing or eliminating losses
# Focus efforts on all of the above attributes, giving priority to:
# -	To those who have greater sales to increase in volume,
#
# -	To those who have greater profits and profitability to increase profits,
#
# -	To those who have loss to reduce or eliminate losses.
